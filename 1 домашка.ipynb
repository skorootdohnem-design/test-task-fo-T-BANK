# %%
from jedi.inference.names import AnonymousParamName

age = 10
name = 'Anna'

# %%
print(name)
# Out:
# Anna

# %%
Name = 'Anna'
surname = 'Balkan'
salary = 150000
experiencs = 1

# %%
salary = [42, 100, 70, 80]
first = salary[0]
print(first)
# Out:
# 42

# %%
users = ['KAT', 'RAD', 'SAK']
users.append('Voronov')
users.append(42)

# %%
users
# Out:
# ['KAT', 'RAD', 'SAK', 'Voronov', 42]

# %%
user_ages = [10, 18, 21, 35, 42, 27, 12, 16]

# %%
for age in user_ages:
    if age > 18:
        print(age)
# Out:
# 21
# 35
# 42
# 27

# %%
worker = ['Olya', 'Silyutina', 350000, 3]
username = worker[0]
user_family = worker[1]
salary = worker[2]
experiencs = worker[3]
if experiencs < 2:
    print('junior')
elif experiencs >= 2 and experiencs <=5:
    print('middle')
else:
    print('master')
# Out:
# middle

# %%
worker = ['Olya', 'Silyutina', 350000, 3]
if worker[3] < 2:
    grade = 'junior'
    print(grade)
elif worker[3] >= 2 and worker[3] <= 5:
    grade = 'middle'
    print(grade)
else:
    print('grade')
# Out:
# middle

# %%
status = f'{worker[0]} and {worker[1]} is {grade}'
print(status)
# Out:
# Olya and Silyutina is middle

# %%
values = [12, 134, 10, 47, 100, 20, 50, 160, 210]
for value in values:
    if value % 10 == 0:
        print(value)
# Out:
# 10
# 100
# 20
# 50
# 160
# 210

# %%
workers = [['Ivan', 'Ivanov', 100000, 2], ['Petr', 'Petrov', 150000, 2], ['Sidor', 'Sidorov', 200000, 3]]
for worker in workers:
    print(worker)
# Out:
# ['Ivan', 'Ivanov', 100000, 2]
# ['Petr', 'Petrov', 150000, 2]
# ['Sidor', 'Sidorov', 200000, 3]

# %%
user_name = worker[0]
user_family = worker[1]
experience = worker[3]

# %%
if experience < 2:
    grade = 'junior'
    print(grade)
elif experience >= 2 and experience <= 5:
    grade = 'middle'
    print(grade)
else:
    grade = 'master'
    print(grade)
# Out:
# middle

# %%
status = f'{worker[0]} {worker[1]} is {grade}'
print(status)
# Out:
# Sidor Sidorov is middle

# %%
x = 0
while x < 10:
    print(x)
    x += 2
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
salary = {'Name' : 'Masha',
          'Surname' : 'Volkova',
          'age' : 25,
          'salary' : 60000,
          'position' : 'junior'
}

# %%
salary
# Out:
# {'Name': 'Masha',
#  'Surname': 'Volkova',
#  'age': 25,
#  'salary': 60000,
#  'position': 'junior'}

# %%
salary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 salary
#
# NameError: name 'salary' is not defined
