# %% [raw]
#        #%%
#        import pandas as pd
#        import seaborn as sns
#        import matplotlib.pyplot as plt
#
#        df = pd.read_csv('D:\\Программы\\Karpov.Courses - Аналитик данных (2022)\\Часть 1\\Задания\\3_taxi_peru.csv', sep = ';')
#        parse_dates=['start_at', 'end_at', 'arrived_at']

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
platform = df['source'].value_counts()
platform

# %%
df1 = {'plat': ['iPhone', 'web', 'Android', 'iPad', 'Wap'],
       'kolvo': [9741, 7631, 4909, 571, 136]
}

total_order = sum(df1['kolvo'])
max_order = max(df1['kolvo'])
itog = round(max_order / total_order * 100)

# %%
ax = sns.barplot(x='plat', y='kolvo', data=df1)

# %%
ikon = df.icon.value_counts()

# %%
sns.countplot(x='end_state', data=df)

# %%
 sns.countplot(x='source',hue='end_state', data=df)

# %%
reiting = df.driver_score.value_counts()
dx = (reiting / reiting.sum()).mul(100).round(2)\
    .reset_index()\
    .rename(columns={'count': 'percentage'})\
    .sort_values('percentage', ascending=False)

# %%
dx

# %%
df.head()

# %%
ax = sns.barplot(x='driver_score', y='percentage', data=dx, color='blue', alpha=0.5)
ax.set(xlabel='Driver score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %%
reiting1 = df.rider_score.value_counts()
dx1 = (reiting1 / reiting1.sum()).mul(100).round(2) \
       .reset_index() \
       .rename(columns={'count': 'percentage'}) \
       .sort_values('percentage', ascending=False)

# %%
dx1

# %%
ax2 = sns.barplot(x='rider_score', y='percentage', data=dx1, color='blue', alpha=0.8)
ax2.set(xlabel='rider_score', ylabel='Percentage')
ax2.show()
