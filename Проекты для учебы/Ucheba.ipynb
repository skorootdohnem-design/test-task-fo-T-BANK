# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('D:\\Программы\\Karpov.Courses - Аналитик данных (2022)\\Часть 1\\Задания\\Данные для Минипроектов\\2_bookings.csv' , sep = ';')

# %%
df.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
succes1 = df.query("reservation_status == 'Check-Out'")
succes = succes1['country'].value_counts()
print(succes)
# Out:
# country
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
#        ...
# KIR        1
# ATF        1
# TJK        1
# SLE        1
# FRO        1
# Name: count, Length: 165, dtype: int64

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
stays_total_nights = df.query('hotel == "Resort Hotel"')\
    [['stays_in_weekend_nights', 'stays_in_week_nights']]\
    .mean()\
    .round(2)
print(stays_total_nights)
# Out:
# stays_in_weekend_nights    1.19
# stays_in_week_nights       3.13
# dtype: float64

# %%
total_night = df.query('hotel == "Resort Hotel"')
stays_total_nights = total_night['stays_in_weekend_nights'] + total_night['stays_in_week_nights']
time2 = stays_total_nights.mean().round(2)
print(time2)
# Out:
# 4.32

# %%
total_night = df.query('hotel == "City Hotel"')
stays_total_nights = total_night['stays_in_weekend_nights'] + total_night['stays_in_week_nights']
time1 = stays_total_nights.mean().round(2)
print(time1)
# Out:
# 2.98

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
sx = df['assigned_room_type'] == df['reserved_room_type']
sx.value_counts()
# Out:
# True     104473
# False     14917
# Name: count, dtype: int64

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
d2016 = df.query('arrival_date_year == 2016')\
    .groupby('arrival_date_month')\
    .size().nlargest(1)

# %%
d2016
# Out:
# arrival_date_month
# October    6203
# dtype: int64

# %%
nn2016 = df.query('arrival_date_year == 2016')\
['arrival_date_month'].value_counts().idxmax()

# %%
nn2016
# Out:
# 'October'

# %%
mn2016 = df.query('arrival_date_year == 2017')\
['arrival_date_month'].value_counts().idxmax()
print(mn2016)
# Out:
# May

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.query('hotel == "City Hotel"')\
    .groupby(['arrival_date_year', 'arrival_date_month'])\
    .agg({'is_canceled': 'count'})\
    .sort_values('is_canceled', ascending = False)\
    .head(10)
# Out:
#                                       is_canceled
# arrival_date_year arrival_date_month
# 2017              May                        4556
# 2016              October                    4219
# 2017              June                       3971
# 2016              June                       3923
# 2017              April                      3919
# 2016              September                  3871
#                   May                        3676
#                   April                      3561
# 2017              July                       3559
# 2015              September                  3529

# %%
df[['adults', 'children', 'babies']]
# Out:
#         adults  children  babies
# 0            2       0.0       0
# 1            2       0.0       0
# 2            1       0.0       0
# 3            1       0.0       0
# 4            2       0.0       0
# ...        ...       ...     ...
# 119385       2       0.0       0
# 119386       3       0.0       0
# 119387       2       0.0       0
# 119388       2       0.0       0
# 119389       2       0.0       0
#
# [119390 rows x 3 columns]

# %%
df[['adults', 'children', 'babies']].mean()\
    .sort_values(ascending=False)
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
df['total_kids'] = df['children'] + df['babies']

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.query('hotel == "Resort Hotel"')['total_kids'].mean()
# Out:
# np.float64(0.14258612081877184)

# %%
df.query('hotel == "City Hotel"')['total_kids'].mean()
# Out:
# np.float64(0.09631142374505207)

# %%
df['has_kids'] = df['total_kids'] > 1

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
df.drop(columns='has_kids', inplace=True)

# %%
df.insert(3, 'has_kids', df['total_kids'] > 1)

# %%
df.drop(columns='has_kids', inplace=True)

# %%
df.insert(2, 'has_kids', df['total_kids'] > 1)

# %%
df.groupby('has_kids')['is_canceled'].mean()
# Out:
# has_kids
# False    0.369182
# True     0.407102
# Name: is_canceled, dtype: float64

# %%
df[df['has_kids'] == False]['is_canceled'].mean()
# Out:
# np.float64(0.36918201967031444)
