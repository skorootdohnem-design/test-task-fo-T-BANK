# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('D:\\Программы\\Karpov.Courses - Аналитик данных (2022)\\Часть 1\\Задания\\Данные для Минипроектов\\2_bookings.csv' , sep = ';')

# %%
df.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head(7)
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
success = df.query('reservation_status == "Check-Out"')

# %%
top_countries = success['country'].value_counts()
top_countries.head()
# Out:
# country
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: count, dtype: int64

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
how_much_night_vihi = df['stays_in_weekend_nights'].mean()
print(how_much_night_vihi)
# Out:
# 0.9275986263506156

# %%
how_much_night_nedek = df['stays_in_week_nights'].mean()
print(how_much_night_nedek)
# Out:
# 2.500301532791691

# %%
how_much_night_nedek
# Out:
# np.float64(2.500301532791691)

# %%
raznica = df['reserved_room_type'] != df['assigned_room_type']
kolvo_raznici = len(raznica)
print(kolvo_raznici)
# Out:
# 119390

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
good_years = df.query('arrival_date_year == 2016')
good_moonth = good_years['arrival_date_month'].value_counts()
most_common_month = good_moonth.idxmax()
count = good_moonth.max()
print(most_common_month , count)
# Out:
# October 6203

# %%
good_years = df.query('arrival_date_year == 2017')
good_moonth = good_years['arrival_date_month'].value_counts()
most_common_month = good_moonth.idxmax()  # возвращает 'September'
count = good_moonth.max()
print(most_common_month , count)
# Out:
# May 6313

# %%
city_hotel = df.query('hotel == "City Hotel" and is_canceled == 1')
horelok = city_hotel.groupby(['arrival_date_year', 'arrival_date_month']).is_canceled.sum().groupby(['arrival_date_year']).nlargest(1)
print(horelok)
# Out:
# arrival_date_year  arrival_date_year  arrival_date_month
# 2015               2015               September             1543
# 2016               2016               October               1947
# 2017               2017               May                   2217
# Name: is_canceled, dtype: int64

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
canceled = df['is_canceled'] == 0
country1 = df[['country', 'canceled']].value_counts()
canceles_only = country1[:, False].head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 canceled = df['is_canceled'] == 0
# ----> 2 country1 = df[['country', 'canceled']].value_counts()
#       3 canceles_only = country1[:, False].head(5)
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
canceles_only

# %%
df.loc[df.is_canceled== 0].country.value_counts().head()

# %%
df.head(5)

# %%
total_night = df.query('hotel == "City Hotel"')
stay_total_night = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
time = stay_total_night.mean().round(0)
print(time)

# %%
df.head()

# %%
raznica = (df['reserved_room_type'] != df['assigned_room_type']).sum()

# %%
df[['adults', 'children', 'babies']].mean()

# %%
df.head()

# %%
df = df.drop('total_kids', axis=1)

# %%
df.head()

# %%
df['total_kids'] = 5
df.rename(columns={'new_columns': 'total_kids'}, inplace=True)
df['total_kids'] = df['children'] + df['babies']

# %%
df.query('hotel == "City Hotel"')\
    .groupby('hotel')['total_kids'].mean()\
    .round(2)
# Out:
# hotel
# City Hotel    0.1
# Name: total_kids, dtype: float64

# %%
df.query('hotel == "Resort Hotel"')\
    .groupby('hotel')['total_kids'].mean()\
    .round(2)
# Out:
# hotel
# Resort Hotel    0.14
# Name: total_kids, dtype: float64

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
df['total_kids'] = df['children'] + df['babies']

# %%
df['has_kids'] = df['total_kids'] > 1

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
stat = df['has_kids'].value_counts()
falce_cound = stat.get(False,0)
true_cound = stat.get(True,0)
total = falce_cound + true_cound
falce_cound1 = (falce_cound / total) * 100
true_cound1 = (true_cound / total) * 100
totalll = (falce_cound1 + true_cound1) / 2
print(totalll)
# Out:
# 50.0
