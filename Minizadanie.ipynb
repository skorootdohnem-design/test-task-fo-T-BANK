# %%
import pandas as pd

# %%
bookings = pd.read_csv(r'D:\Программы\Karpov.Courses - Аналитик данных (2022)\Часть 1\Задания\Данные для Минипроектов\2_bookings.csv' , sep = ';')

# %%
bookings.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
rows, cols = bookings.shape
print(f'{rows}, {cols}')
# Out:
# 119390, 21

# %%
bookings_head.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 bookings_head.dtypes
#
# NameError: name 'bookings_head' is not defined

# %%
bookings_head.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 bookings_head.info()
#
# NameError: name 'bookings_head' is not defined

# %%
bookings = df.rename(columns=lambda x: x.lower())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bookings = df.rename(columns=lambda x: x.lower())
#
# NameError: name 'df' is not defined

# %%
bookings_head = df.rename(columns=lambda x: x.replace(' ', '_'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 bookings_head = df.rename(columns=lambda x: x.replace(' ', '_'))
#
# NameError: name 'df' is not defined

# %%
bookings_head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bookings_head
#
# NameError: name 'bookings_head' is not defined

# %%
top5 = bookings.loc[bookings.is_canceled == 0].country.value_counts().head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9944\1754176266.py in ?()
# ----> 1 top5 = bookings.loc[bookings.is_canceled == 0].country.value_counts().head
#
# ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'is_canceled'

# %%
top5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 top5
#
# NameError: name 'top5' is not defined

# %%
Total_nights = bookings.groupby('hotel').stays_total_nights.mean().round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Total_nights = bookings.groupby('hotel').stays_total_nights.mean().round(2)
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
Total_nights
