# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('D:\\Программы\\Karpov.Courses - Аналитик данных (2022)\\Часть 1\\Задания\\Данные для Минипроектов\\5_transaction_data.csv')

# %%
df.head()
# Out:
#                   date                name  transaction
# 0  2020-03-02 00:37:20   Ekaterina_Petrova    cancelled
# 1  2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2  2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 3  2020-03-02 00:02:58    Lolita_Polyanova    cancelled
# 4  2020-03-02 00:17:52      Julia_Smirnova    cancelled

# %%
df.shape
# Out:
# (5315, 3)

# %%
df['transaction'].value_counts()
# Out:
# transaction
# successfull    3692
# cancelled      1619
# error             4
# Name: count, dtype: int64

# %%
successfull_client = df.query('transaction == "successfull"')

# %%
grupp_succs = successfull_client.groupby('name', as_index=False)['transaction'].count()\
    .sort_values(['transaction'], ascending=False)
grupp_succs['transaction'].describe()
# Out:
# count    56.000000
# mean     65.928571
# std       7.787769
# min      46.000000
# 25%      61.000000
# 50%      64.000000
# 75%      72.000000
# max      82.000000
# Name: transaction, dtype: float64

# %%
ax = sns.histplot(grupp_succs['transaction'], stat='probability', bins=20)

# %%
df.head()
# Out:
#                   date                name  transaction
# 0  2020-03-02 00:37:20   Ekaterina_Petrova    cancelled
# 1  2020-03-02 00:59:09      Irina_Fedorova  successfull
# 2  2020-03-02 01:06:14  Ekaterina_Smirnova  successfull
# 3  2020-03-02 00:02:58    Lolita_Polyanova    cancelled
# 4  2020-03-02 00:17:52      Julia_Smirnova    cancelled
